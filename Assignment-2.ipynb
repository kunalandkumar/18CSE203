# %%
import pandas as pd
import numpy as np

# %%
#load data
df=pd.read_csv("https://raw.githubusercontent.com/kunalandkumar/18CSE203/main/the_grammy_awards.csv")

# %%
df.shape
# Out:
# (4810, 10)

# %%
df.head
# Out:
# <bound method NDFrame.head of       year                              title               published_at  \
# 0     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 1     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 2     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 3     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 4     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 5     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 6     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 7     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 8     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 9     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 10    2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# ...

# %%
df
# Out:
#       year                              title               published_at  \
# 0     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 1     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 2     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 3     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 4     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 5     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 6     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 7     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 8     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 9     2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 10    2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 11    2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# ...

# %%
df.columns
# Out:
# Index(['year', 'title', 'published_at', 'updated_at', 'category', 'nominee',
#        'artist', 'workers', 'img', 'winner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4810 entries, 0 to 4809
# Data columns (total 10 columns):
# year            4810 non-null int64
# title           4810 non-null object
# published_at    4810 non-null object
# updated_at      4810 non-null object
# category        4810 non-null object
# nominee         4804 non-null object
# artist          2970 non-null object
# workers         2620 non-null object
# img             3443 non-null object
# winner          4810 non-null bool
# dtypes: bool(1), int64(1), object(8)
# memory usage: 343.0+ KB

# %%
df.artist.unique()
# Out:
# array(['Billie Eilish', 'Bon Iver', 'Ariana Grande', ..., 'The Champs',
#        'Stan Freberg',
#        'David Seville And The Chipmunks (Ross Bagdasarian, Sr.)'],
#       dtype=object)

# %%
df.winner.unique()
# Out:
# array([ True])

# %%
df.describe()
# Out:
#               year
# count  4810.000000
# mean   1995.566944
# std      17.149720
# min    1958.000000
# 25%    1983.000000
# 50%    1998.000000
# 75%    2010.000000
# max    2019.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# year               0
# title              0
# published_at       0
# updated_at         0
# category           0
# nominee            6
# artist          1840
# workers         2190
# img             1367
# winner             0
# dtype: int64
